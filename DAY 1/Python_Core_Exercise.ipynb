# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshitha94127/NASSCOM/blob/main/Python_Core_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random
print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------

# %%
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}
# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1
raw_sensor_data = []
for i in range(100):
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    device_id = f"DEV{i+1:03}"
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)
    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)
    reading = (timestamp, device_id, device_type, location, value)
    raw_sensor_data.append(reading)
for reading in raw_sensor_data[:5]:
    print(reading)
# Out:
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-29 12:42:14', 'DEV001', 'Humidity_Sensor', 'OfficeA', 30.26)
# ('2026-07-29 12:42:14', 'DEV002', 'Light_Sensor', 'OfficeB', 706.58)
# ('2026-07-29 12:42:14', 'DEV003', 'Temperature_Sensor', 'Warehouse', 23.37)
# ('2026-07-29 12:42:14', 'DEV004', 'Humidity_Sensor', 'OfficeB', 53.39)
# ('2026-07-29 12:42:14', 'DEV005', 'Temperature_Sensor', 'Lab1', 21.36)

# %%
#task 1.2
temperature_readings = []
for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading
    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

# %%
#task 1.3
print(temperature_readings[:5])
unique_locations = set()
for reading in raw_sensor_data:
    unique_locations.add(reading[3])
print(unique_locations)
# Out:
# [{'timestamp': '2026-07-29 12:42:14', 'device_id': 'DEV003', 'location': 'Warehouse', 'temperature_celsius': 23.37}, {'timestamp': '2026-07-29 12:42:14', 'device_id': 'DEV005', 'location': 'Lab1', 'temperature_celsius': 21.36}, {'timestamp': '2026-07-29 12:42:14', 'device_id': 'DEV012', 'location': 'Warehouse', 'temperature_celsius': 21.06}, {'timestamp': '2026-07-29 12:42:14', 'device_id': 'DEV019', 'location': 'Warehouse', 'temperature_celsius': 29.26}, {'timestamp': '2026-07-29 12:42:14', 'device_id': 'DEV025', 'location': 'Warehouse', 'temperature_celsius': 20.4}]
# {'Lab1', 'Warehouse', 'OfficeB', 'OfficeA', 'Lab2'}

# %%
#task 1.4
device_stats = {}
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]
    current_min, current_max = device_stats[device_type]
    if value < current_min:
        current_min = value
    if value > current_max:
        current_max = value
    device_stats[device_type] = (current_min, current_max)
print(device_stats)
# Out:
# {'Temperature_Sensor': (18.14, 29.81), 'Humidity_Sensor': (30.26, 79.89), 'Pressure_Sensor': (980.82, 1027.04), 'Light_Sensor': (270.93, 987.08)}

# %%
sliced_readings_1 = raw_sensor_data[9:20]
print(sliced_readings_1)
sliced_readings_2 = raw_sensor_data[::5]
print(sliced_readings_2)
# Out:
# [('2026-07-29 12:42:14', 'DEV010', 'Light_Sensor', 'Lab1', 877.35), ('2026-07-29 12:42:14', 'DEV011', 'Humidity_Sensor', 'Lab2', 75.98), ('2026-07-29 12:42:14', 'DEV012', 'Temperature_Sensor', 'Warehouse', 21.06), ('2026-07-29 12:42:14', 'DEV013', 'Pressure_Sensor', 'Lab2', 980.98), ('2026-07-29 12:42:14', 'DEV014', 'Humidity_Sensor', 'OfficeA', 50.09), ('2026-07-29 12:42:14', 'DEV015', 'Pressure_Sensor', 'OfficeB', 1019.64), ('2026-07-29 12:42:14', 'DEV016', 'Pressure_Sensor', 'Lab2', 986.85), ('2026-07-29 12:42:14', 'DEV017', 'Humidity_Sensor', 'Lab2', 60.7), ('2026-07-29 12:42:14', 'DEV018', 'Pressure_Sensor', 'OfficeA', 985.79), ('2026-07-29 12:42:14', 'DEV019', 'Temperature_Sensor', 'Warehouse', 29.26), ('2026-07-29 12:42:14', 'DEV020', 'Light_Sensor', 'Lab2', 543.51)]
# [('2026-07-29 12:42:14', 'DEV001', 'Humidity_Sensor', 'OfficeA', 30.26), ('2026-07-29 12:42:14', 'DEV006', 'Light_Sensor', 'Lab2', 373.39), ('2026-07-29 12:42:14', 'DEV011', 'Humidity_Sensor', 'Lab2', 75.98), ('2026-07-29 12:42:14', 'DEV016', 'Pressure_Sensor', 'Lab2', 986.85), ('2026-07-29 12:42:14', 'DEV021', 'Humidity_Sensor', 'Lab1', 66.65), ('2026-07-29 12:42:14', 'DEV026', 'Humidity_Sensor', 'Warehouse', 67.01), ('2026-07-29 12:42:14', 'DEV031', 'Light_Sensor', 'Warehouse', 295.67), ('2026-07-29 12:42:14', 'DEV036', 'Pressure_Sensor', 'OfficeA', 1027.04), ('2026-07-29 12:42:14', 'DEV041', 'Pressure_Sensor', 'Lab2', 995.44), ('2026-07-29 12:42:14', 'DEV046', 'Light_Sensor', 'Warehouse', 533.81), ('2026-07-29 12:42:14', 'DEV051', 'Light_Sensor', 'Lab1', 715.06), ('2026-07-29 12:42:14', 'DEV056', 'Pressure_Sensor', 'Lab1', 984.16), ('2026-07-29 12:42:14', 'DEV061', 'Pressure_Sensor', 'Warehouse', 1004.29), ('2026-07-29 12:42:14', 'DEV066', 'Temperature_Sensor', 'OfficeB', 28.99), ('2026-07-29 12:42:14', 'DEV071', 'Pressure_Sensor', 'OfficeB', 1020.02), ('2026-07-29 12:42:14', 'DEV076', 'Pressure_Sensor', 'OfficeA', 983.05), ('2026-07-29 12:42:14', 'DEV081', 'Light_Sensor', 'Lab2', 521.66), ('2026-07-29 12:42:14', 'DEV086', 'Humidity_Sensor', 'OfficeB', 58.73), ('2026-07-29 12:42:14', 'DEV091', 'Light_Sensor', 'Warehouse', 639.74), ('2026-07-29 12:42:14', 'DEV096', 'Temperature_Sensor', 'Lab1', 29.24)]

# %%
#task 1.5.2
sample_string = "PythonProgrammingIsFun"
substring_1 = sample_string[6:17]
print(substring_1)
substring_2 = sample_string[5::-1]
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
#task 1.5.3
fifth_reading_device_type = raw_sensor_data[4][2]
print(fifth_reading_device_type)
device_type_suffix = fifth_reading_device_type[-6:]
print(device_type_suffix)
# Out:
# Temperature_Sensor
# Sensor

# %%
#task 2.1
def get_readings_by_location(readings_list, target_location):
    result = []
    for reading in readings_list:
        if reading[2] == target_location:
            result.append(reading)
    return result

# %%
#task 2.2
def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0
    total = 0
    for data in temp_data_list:
        total += data["temperature_celsius"]
    return total / len(temp_data_list)

# %%
#task 2.3
def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

# %%
#task 3.1
reports_dir = 'sensor_reports'
if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# Directory 'sensor_reports' created.

# %%
#task 3.2
if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]
    # Convert string to datetime object
    # The format string must exactly match the timestamp string
    date_format = '%Y-%m-%d %H:%M:%S'
    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)
    duration = last_dt - first_dt
    days = duration.days
    seconds = duration.total_seconds()
    hours = int(seconds // 3600) % 24 # Calculate remaining hours after full days
    minutes = int((seconds % 3600) // 60) # Calculate remaining minutes after full hours
    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
#task 3.3
random_values = []
for i in range(5):
    random_values.append(random.randint(100, 200))
print(random_values)
# Out:
# [178, 177, 146, 165, 127]

# %%
#task 4.1
report_filename = os.path.join(reports_dir, "temperature_report.txt")
try:
    with open(report_filename, "w") as f:
        for reading_dict in temperature_readings:
            line = f"[{reading_dict.get('timestamp','')}] Device {reading_dict.get('device_id','')} at {reading_dict.get('location','')}: {reading_dict.get('temperature_celsius','')}°C"
            f.write(line + "\n")
    print(f"Temperature report written to '{report_filename}'")
except IOError as e:
    print(f"Error writing file: {e}")
# Out:
# Temperature report written to 'sensor_reports/temperature_report.txt'

# %%
#task 4.2
read_report_lines = []
try:
    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()
    print("First 3 lines of the report:")
    for line in read_report_lines[:3]:
        print(line.strip())
except IOError as e:
    print(f"Error reading file: {e}")
# Out:
# First 3 lines of the report:
# [] Device  at New York: °C
# [] Device  at London: °C
# [] Device  at Tokyo: °C

# %%
print("\n--- Exercise Complete! ---")
print("Great job completing the intermediate Python exercise.")
print("Review your code and outputs to ensure correctness and understanding of all concepts.")
print("Consider adding more complex scenarios or user inputs for further practice.")
# Out:
# --- Exercise Complete! ---
# Great job completing the intermediate Python exercise.
# Review your code and outputs to ensure correctness and understanding of all concepts.
# Consider adding more complex scenarios or user inputs for further practice.
